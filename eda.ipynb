# %% [markdown]
# # EDA and upload to Neon

# %%
import pandas as pd 

df = pd.read_csv("disease_outbreaks_HDX.csv")

df.head()
# Out:
#        id_outbreak        Year                                                                         icd10n  \
# 0  #Year+iso3+icd4  #date+year                                                              #disease+name+icd
# 1      2025AGOA000        2025                                                 Intestinal infectious diseases
# 2      2025ALBU071        2025  Provisional assignment of new diseases of uncertain etiology or emergency use
# 3       2025ARGB05        2025             Viral infections characterized by skin and mucous membrane lesions
# 4      2025ARGU071        2025  Provisional assignment of new diseases of uncertain etiology or emergency use
#
#                 icd103n                     icd104n             icd10c             icd103c             icd104c  \
# 0    #disease+name+icd3          #disease+name+icd4  #disease+code+icd  #disease+code+icd3  #disease+code+icd4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3209 entries, 0 to 3208
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id_outbreak     3209 non-null   object
#  1   Year            3209 non-null   object
#  2   icd10n          3209 non-null   object
#  3   icd103n         3209 non-null   object
#  4   icd104n         3209 non-null   object
#  5   icd10c          3209 non-null   object
#  6   icd103c         3209 non-null   object
#  7   icd104c         3209 non-null   object
#  8   Disease         3209 non-null   object
#  9   Definition      3089 non-null   object
#  10  Country         3209 non-null   object
#  11  iso2            3205 non-null   object
#  12  iso3            3209 non-null   object
#  13  unsd_region     3202 non-null   object
#  14  unsd_subregion  3202 non-null   object
#  15  who_region      2958 non-null   object
#  16  DONs            3209 non-null   object
# ...

# %%
df.describe()
# Out:
#             id_outbreak  Year  \
# count              3209  3209
# unique             3209    31
# top     #Year+iso3+icd4  2022
# freq                  1   418
#
#                                                    icd10n  \
# count                                                3209
# unique                                                 25
# top     Provisional assignment of new diseases of unce...
# freq                                                 1197
#
#                      icd103n                     icd104n   icd10c icd103c  \
# count                   3209                        3209     3209    3209
# unique                    60                          92       24      59
# top     Emergency use of U07  COVID-19, virus identified  U00-U49     U07
# freq                    1122                        1122     1231    1122
#
#        icd104c   Disease                                         Definition  \
# ...

# %%
psql 'postgresql://neondb_owner:npg_SBXuCaUgE50l@ep-little-truth-abzgs476-pooler.eu-west-2.aws.neon.tech/gs?sslmode=require&channel_binding=require'

# %%
import pandas as pd
from sqlalchemy import create_engine

try:
    # Use existing SQLAlchemy engine if available
    if 'engine' in globals() and engine is not None:
        print("Using existing SQLAlchemy engine")
        df = pd.read_sql_query("SELECT * FROM outbreaks", engine)
    else:
        # Create a new SQLAlchemy engine
        print("Creating new SQLAlchemy engine")
        conn_string = "postgresql://neondb_owner:npg_SBXuCaUgE50l@ep-little-truth-abzgs476-pooler.eu-west-2.aws.neon.tech/gs?sslmode=require&channel_binding=require"
        # Convert to SQLAlchemy format
        sqlalchemy_conn = f"postgresql+psycopg://{conn_string.split('://', 1)[1]}"
        engine = create_engine(sqlalchemy_conn)
        df = pd.read_sql_query("SELECT * FROM outbreaks", engine)

    print(f"Data loaded successfully: {len(df)} rows")
    df.head()
    
except Exception as e:
    print("Connection failed or query error.")
    print(e)
# Out:
# Using existing SQLAlchemy engine
# Data loaded successfully: 3208 rows

# %%
df.head()
# Out:
#    id_outbreak  year                                                                         icd10n  \
# 0  2025AGOA000  2025                                                 Intestinal infectious diseases
# 1  2025ALBU071  2025  Provisional assignment of new diseases of uncertain etiology or emergency use
# 2   2025ARGB05  2025             Viral infections characterized by skin and mucous membrane lesions
# 3  2025ARGU071  2025  Provisional assignment of new diseases of uncertain etiology or emergency use
# 4  2025ARMU071  2025  Provisional assignment of new diseases of uncertain etiology or emergency use
#
#                 icd103n                     icd104n   icd10c icd103c icd104c   disease  \
# 0               Cholera           Classical cholera  A00-A09     A00    A000   Cholera
# 1  Emergency use of U07  COVID-19, virus identified  U00-U49     U07    U071  COVID-19
# 2               Measles                     Measles  B00-B09     B05     B05   Measles
# ...

# %%
second_df = pd.read_csv("disease_outbreaks_HDX.csv")

print(second_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3209 entries, 0 to 3208
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id_outbreak     3209 non-null   object
#  1   Year            3209 non-null   object
#  2   icd10n          3209 non-null   object
#  3   icd103n         3209 non-null   object
#  4   icd104n         3209 non-null   object
#  5   icd10c          3209 non-null   object
#  6   icd103c         3209 non-null   object
#  7   icd104c         3209 non-null   object
#  8   Disease         3209 non-null   object
#  9   Definition      3089 non-null   object
#  10  Country         3209 non-null   object
#  11  iso2            3205 non-null   object
#  12  iso3            3209 non-null   object
#  13  unsd_region     3202 non-null   object
#  14  unsd_subregion  3202 non-null   object
#  15  who_region      2958 non-null   object
#  16  DONs            3209 non-null   object
# ...
